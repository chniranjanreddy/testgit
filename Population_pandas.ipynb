# %% [markdown]
# # Reading population data and analysing the statistics

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df1 = pd.read_excel ("population_total (1).xlsx",0) #read excel
df1.head()
# Out:
#                 1800     1801     1802     1803     1804     1805     1806  \
# Afghanistan  3280000  3280000  3280000  3280000  3280000  3280000  3280000
# Albania       410000   412000   413000   414000   416000   417000   418000
# Algeria      2500000  2510000  2520000  2530000  2540000  2550000  2560000
# Andorra         2650     2650     2650     2650     2650     2650     2650
# Angola       1570000  1570000  1570000  1570000  1570000  1570000  1570000
#
#                 1807     1808     1809    ...           2091       2092  \
# Afghanistan  3280000  3280000  3280000    ...       71900000   71800000
# Albania       420000   421000   422000    ...        1820000    1800000
# Algeria      2570000  2580000  2590000    ...       62800000   62800000
# Andorra         2650     2650     2650    ...          64300      64200
# Angola       1570000  1570000  1570000    ...      156000000  158000000
#
#                   2093       2094       2095       2096       2097       2098  \
# ...

# %%
df3=df1.T
df3.head()
# Out:
#       Afghanistan  Albania  Algeria  Andorra   Angola  Antigua and Barbuda  \
# 1800      3280000   410000  2500000     2650  1570000                37000
# 1801      3280000   412000  2510000     2650  1570000                37000
# 1802      3280000   413000  2520000     2650  1570000                37000
# 1803      3280000   414000  2530000     2650  1570000                37000
# 1804      3280000   416000  2540000     2650  1570000                37000
#
#       Argentina  Armenia  Australia  Austria    ...     United Kingdom  \
# 1800     534000   413000     351000  3210000    ...           12300000
# 1801     534000   413000     350000  3210000    ...           12500000
# 1802     534000   413000     349000  3220000    ...           12600000
# 1803     534000   413000     348000  3230000    ...           12800000
# 1804     534000   413000     348000  3240000    ...           13000000
#
#       United States  Uruguay  Uzbekistan  Vanuatu  Venezuela  Vietnam  \
# ...

# %%
df3.insert(0,column='year',value=df3.index)

# %%
df3.head()
# Out:
#       year  Afghanistan  Albania  Algeria  Andorra   Angola  \
# 1800  1800      3280000   410000  2500000     2650  1570000
# 1801  1801      3280000   412000  2510000     2650  1570000
# 1802  1802      3280000   413000  2520000     2650  1570000
# 1803  1803      3280000   414000  2530000     2650  1570000
# 1804  1804      3280000   416000  2540000     2650  1570000
#
#       Antigua and Barbuda  Argentina  Armenia  Australia    ...     \
# 1800                37000     534000   413000     351000    ...
# 1801                37000     534000   413000     350000    ...
# 1802                37000     534000   413000     349000    ...
# 1803                37000     534000   413000     348000    ...
# 1804                37000     534000   413000     348000    ...
#
#       United Kingdom  United States  Uruguay  Uzbekistan  Vanuatu  Venezuela  \
# 1800        12300000        6800000    55000     1920000    27800     718000
# ...

# %%
ax = df3.plot(kind='line',x='year',y='China')
df3.plot(ax=ax,kind='line',x='year',y='India')

# %%
df4=df1
df4.insert(0,column='country',value=df4.index)

# %%
df4.head()
# Out:
#                  country     1800     1801     1802     1803     1804  \
# Afghanistan  Afghanistan  3280000  3280000  3280000  3280000  3280000
# Albania          Albania   410000   412000   413000   414000   416000
# Algeria          Algeria  2500000  2510000  2520000  2530000  2540000
# Andorra          Andorra     2650     2650     2650     2650     2650
# Angola            Angola  1570000  1570000  1570000  1570000  1570000
#
#                 1805     1806     1807     1808    ...           2091  \
# Afghanistan  3280000  3280000  3280000  3280000    ...       71900000
# Albania       417000   418000   420000   421000    ...        1820000
# Algeria      2550000  2560000  2570000  2580000    ...       62800000
# Andorra         2650     2650     2650     2650    ...          64300
# Angola       1570000  1570000  1570000  1570000    ...      156000000
#
#                   2092       2093       2094       2095       2096       2097  \
# ...

# %%
pop_sort_1800 = df4[1800].sort_values(ascending=False).head(10)
pop_sort_2019 = df4[2019].sort_values(ascending=False).head(10)
pop_sort_2050 = df4[2050].sort_values(ascending=False).head(10)
pop_sort_2050
# Out:
# India               1660000000
# China               1360000000
# Nigeria              411000000
# United States        390000000
# Indonesia            322000000
# Pakistan             307000000
# Brazil               233000000
# Bangladesh           202000000
# Congo, Dem. Rep.     197000000
# Ethiopia             191000000
# Name: 2050, dtype: int64

# %%
pop_sort_1800.plot(kind='bar')

# %%
pop_sort_2019.plot(kind='bar')

# %%
pop_sort_2050.plot(kind='bar')
